# %% [markdown]
# # BRIEF TEMPLATE
#
# **Date:** [INSERT DATE]
# **Period:** Fiscal Year [INSERT YEAR]
# **Subject:** [INSERT CATEGORY] Budget Variance
#
#
# ---
#
# ## EXECUTIVE SUMMARY
#
# [INSERT CATEGORY] spending came in $[INSERT AMOUNT]B [over/under] budget in FY[INSERT YEAR] ([INSERT PERCENTAGE]% variance). The primary driver was [INSERT DRIVER]. This represents the [INSERT RANK] variance across all spending categories.
#
# Recommendation: [INSERT ACTION] by [INSERT TIMELINE] to [INSERT OUTCOME].
#
# ---
#
# ## WHAT HAPPENED
#
# **Primary variance:** [INSERT CATEGORY]
#
# We budgeted $[INSERT BUDGET]B for the year.
# Actual spending was $[INSERT ACTUAL]B.
# Variance: [+/-]$[INSERT VARIANCE]B ([+/-][INSERT PERCENTAGE]%)
#
# This category falls under Tier [INSERT TIER] ([INSERT TIER NAME]) in the priority framework.
#
# **Scale of the issue:**
# - Dollar impact: $[INSERT AMOUNT]B [over/under] budget
# - Percentage impact: [INSERT PERCENTAGE]% deviation from plan
# - Relative ranking: [INSERT RANK] among all budget categories
#
# **Prior year comparison:**
#
# FY[INSERT PRIOR YEAR] results:
# - Budget: $[INSERT PRIOR BUDGET]B
# - Actual: $[INSERT PRIOR ACTUAL]B
# - Variance: [+/-]$[INSERT PRIOR VARIANCE]B ([INSERT PERCENTAGE]%)
#
# **Trend:** [INSERT TREND DESCRIPTION]
#
# ---
#
# ## WHY IT HAPPENED
#
# **Primary driver:**
#
# [INSERT DRIVER EXPLANATION]
#
# **Contributing factors:**
#
# 1. [INSERT FACTOR 1]: [INSERT EXPLANATION]
#
# 2. [INSERT FACTOR 2]: [INSERT EXPLANATION]
#
# 3. [INSERT FACTOR 3]: [INSERT EXPLANATION]
#
# ---
#
# ## RECOMMENDED ACTIONS
#
# ### First priority: [INSERT ACTION TITLE]
#
# [INSERT ACTION DESCRIPTION]
#
# Details:
# - Owner: [INSERT OWNER]
# - Timeline: [INSERT TIMELINE]
# - Expected outcome: [INSERT OUTCOME]
#
# ### Second priority: [INSERT ACTION 2 TITLE]
#
# [INSERT ACTION 2 DESCRIPTION]
#
# Details:
# - Owner: [INSERT OWNER 2]
# - Timeline: [INSERT TIMELINE 2]
# - Expected outcome: [INSERT OUTCOME 2]
#
# ---
#
# ## CONFIDENCE AND ASSUMPTIONS
#
# **Confidence level:** [INSERT HIGH/MEDIUM/LOW] ([INSERT SCORE]%)
#
# Basis for confidence:
# - Data quality: [INSERT DATA QUALITY ASSESSMENT]
# - Pattern consistency: [INSERT PATTERN ASSESSMENT]
# - Driver clarity: [INSERT DRIVER CLARITY ASSESSMENT]
#
# **Key assumptions:**
#
# 1. [INSERT ASSUMPTION 1]
# 2. [INSERT ASSUMPTION 2]
# 3. [INSERT ASSUMPTION 3]
#
# **Factors that could change this assessment:**
#
# 1. [INSERT RISK 1]
# 2. [INSERT RISK 2]
#
# ---
#
# ## NEXT STEPS
#
# **Immediate actions (next 30 days):**
# - [INSERT STEP 1]
# - [INSERT STEP 2]
#
# **Near-term actions (60-90 days):**
# - [INSERT STEP 3]
# - [INSERT STEP 4]
#
# **Next review date:** [INSERT DATE]
#
# **Escalation required:** [YES/NO]
#
# ---
#
# **Data source:** federal_budget_2023_2024.csv
# **Generated:** [INSERT TIMESTAMP]
